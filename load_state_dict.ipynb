# %%
import torch
from denoising_diffusion_pytorch import Unet, GaussianDiffusion

# %% [markdown]
# # model

# %%
# gen model
model = Unet(dim=64, dim_mults=(1, 2, 4, 8))

# %%
diffusion = GaussianDiffusion(
    model,
    image_size=128,
    timesteps=1000,  # number of steps
    sampling_timesteps=250,  # number of sampling timesteps (using ddim for faster inference [see citation for ddim paper])
)

# %% [markdown]
# # load weight

# %%
runs = "200"
state_dict: dict = torch.load(f"results/flowers/200000/model-{runs}.pt")
print(state_dict.keys())  # ['step', 'model', 'opt', 'ema', 'scaler', 'version']
# Out:
# dict_keys(['step', 'model', 'opt', 'ema', 'scaler', 'version'])

# %% [markdown]
# # get model keys

# %%
model_dict: dict = state_dict["model"]

# %%
model_keys = model_dict.keys()
print(len(model_keys))
model_keys
# Out:
# 287
# odict_keys(['betas', 'alphas_cumprod', 'alphas_cumprod_prev', 'sqrt_alphas_cumprod', 'sqrt_one_minus_alphas_cumprod', 'log_one_minus_alphas_cumprod', 'sqrt_recip_alphas_cumprod', 'sqrt_recipm1_alphas_cumprod', 'posterior_variance', 'posterior_log_variance_clipped', 'posterior_mean_coef1', 'posterior_mean_coef2', 'loss_weight', 'model.init_conv.weight', 'model.init_conv.bias', 'model.time_mlp.1.weight', 'model.time_mlp.1.bias', 'model.time_mlp.3.weight', 'model.time_mlp.3.bias', 'model.downs.0.0.mlp.1.weight', 'model.downs.0.0.mlp.1.bias', 'model.downs.0.0.block1.proj.weight', 'model.downs.0.0.block1.proj.bias', 'model.downs.0.0.block1.norm.weight', 'model.downs.0.0.block1.norm.bias', 'model.downs.0.0.block2.proj.weight', 'model.downs.0.0.block2.proj.bias', 'model.downs.0.0.block2.norm.weight', 'model.downs.0.0.block2.norm.bias', 'model.downs.0.1.mlp.1.weight', 'model.downs.0.1.mlp.1.bias', 'model.downs.0.1.block1.proj.weight', 'model.downs.0.1.block1.proj.bias', 'model.downs.0.1.block1.norm.weight', 'model.downs.0.1.block1.norm.bias', 'model.downs.0.1.block2.proj.weight', 'model.downs.0.1.block2.proj.bias', 'model.downs.0.1.block2.norm.weight', 'model.downs.0.1.block2.norm.bias', 'model.downs.0.2.norm.g', 'model.downs.0.2.to_qkv.weight', 'model.downs.0.2.to_out.0.weight', 'model.downs.0.2.to_out.0.bias', 'model.downs.0.2.to_out.1.g', 'model.downs.0.3.1.weight', 'model.downs.0.3.1.bias', 'model.downs.1.0.mlp.1.weight', 'model.downs.1.0.mlp.1.bias', 'model.downs.1.0.block1.proj.weight', 'model.downs.1.0.block1.proj.bias', 'model.downs.1.0.block1.norm.weight', 'model.downs.1.0.block1.norm.bias', 'model.downs.1.0.block2.proj.weight', 'model.downs.1.0.block2.proj.bias', 'model.downs.1.0.block2.norm.weight', 'model.downs.1.0.block2.norm.bias', 'model.downs.1.1.mlp.1.weight', 'model.downs.1.1.mlp.1.bias', 'model.downs.1.1.block1.proj.weight', 'model.downs.1.1.block1.proj.bias', 'model.downs.1.1.block1.norm.weight', 'model.downs.1.1.block1.norm.bias', 'model.downs.1.1.block2.proj.weight', 'model.downs.1.1.block2.proj.bias', 'model.downs.1.1.block2.norm.weight', 'model.downs.1.1.block2.norm.bias', 'model.downs.1.2.norm.g', 'model.downs.1.2.to_qkv.weight', 'model.downs.1.2.to_out.0.weight', 'model.downs.1.2.to_out.0.bias', 'model.downs.1.2.to_out.1.g', 'model.downs.1.3.1.weight', 'model.downs.1.3.1.bias', 'model.downs.2.0.mlp.1.weight', 'model.downs.2.0.mlp.1.bias', 'model.downs.2.0.block1.proj.weight', 'model.downs.2.0.block1.proj.bias', 'model.downs.2.0.block1.norm.weight', 'model.downs.2.0.block1.norm.bias', 'model.downs.2.0.block2.proj.weight', 'model.downs.2.0.block2.proj.bias', 'model.downs.2.0.block2.norm.weight', 'model.downs.2.0.block2.norm.bias', 'model.downs.2.1.mlp.1.weight', 'model.downs.2.1.mlp.1.bias', 'model.downs.2.1.block1.proj.weight', 'model.downs.2.1.block1.proj.bias', 'model.downs.2.1.block1.norm.weight', 'model.downs.2.1.block1.norm.bias', 'model.downs.2.1.block2.proj.weight', 'model.downs.2.1.block2.proj.bias', 'model.downs.2.1.block2.norm.weight', 'model.downs.2.1.block2.norm.bias', 'model.downs.2.2.norm.g', 'model.downs.2.2.to_qkv.weight', 'model.downs.2.2.to_out.0.weight', 'model.downs.2.2.to_out.0.bias', 'model.downs.2.2.to_out.1.g', 'model.downs.2.3.1.weight', 'model.downs.2.3.1.bias', 'model.downs.3.0.mlp.1.weight', 'model.downs.3.0.mlp.1.bias', 'model.downs.3.0.block1.proj.weight', 'model.downs.3.0.block1.proj.bias', 'model.downs.3.0.block1.norm.weight', 'model.downs.3.0.block1.norm.bias', 'model.downs.3.0.block2.proj.weight', 'model.downs.3.0.block2.proj.bias', 'model.downs.3.0.block2.norm.weight', 'model.downs.3.0.block2.norm.bias', 'model.downs.3.1.mlp.1.weight', 'model.downs.3.1.mlp.1.bias', 'model.downs.3.1.block1.proj.weight', 'model.downs.3.1.block1.proj.bias', 'model.downs.3.1.block1.norm.weight', 'model.downs.3.1.block1.norm.bias', 'model.downs.3.1.block2.proj.weight', 'model.downs.3.1.block2.proj.bias', 'model.downs.3.1.block2.norm.weight', 'model.downs.3.1.block2.norm.bias', 'model.downs.3.2.nor ...

# %%
diffusion.load_state_dict(model_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # get ema keys

# %%
ema_dict: dict = state_dict["ema"]

# %%
ema_keys = ema_dict.keys()
print(len(ema_keys))
ema_keys
# Out:
# 576
# odict_keys(['initted', 'step', 'online_model.betas', 'online_model.alphas_cumprod', 'online_model.alphas_cumprod_prev', 'online_model.sqrt_alphas_cumprod', 'online_model.sqrt_one_minus_alphas_cumprod', 'online_model.log_one_minus_alphas_cumprod', 'online_model.sqrt_recip_alphas_cumprod', 'online_model.sqrt_recipm1_alphas_cumprod', 'online_model.posterior_variance', 'online_model.posterior_log_variance_clipped', 'online_model.posterior_mean_coef1', 'online_model.posterior_mean_coef2', 'online_model.loss_weight', 'online_model.model.init_conv.weight', 'online_model.model.init_conv.bias', 'online_model.model.time_mlp.1.weight', 'online_model.model.time_mlp.1.bias', 'online_model.model.time_mlp.3.weight', 'online_model.model.time_mlp.3.bias', 'online_model.model.downs.0.0.mlp.1.weight', 'online_model.model.downs.0.0.mlp.1.bias', 'online_model.model.downs.0.0.block1.proj.weight', 'online_model.model.downs.0.0.block1.proj.bias', 'online_model.model.downs.0.0.block1.norm.weight', 'online_model.model.downs.0.0.block1.norm.bias', 'online_model.model.downs.0.0.block2.proj.weight', 'online_model.model.downs.0.0.block2.proj.bias', 'online_model.model.downs.0.0.block2.norm.weight', 'online_model.model.downs.0.0.block2.norm.bias', 'online_model.model.downs.0.1.mlp.1.weight', 'online_model.model.downs.0.1.mlp.1.bias', 'online_model.model.downs.0.1.block1.proj.weight', 'online_model.model.downs.0.1.block1.proj.bias', 'online_model.model.downs.0.1.block1.norm.weight', 'online_model.model.downs.0.1.block1.norm.bias', 'online_model.model.downs.0.1.block2.proj.weight', 'online_model.model.downs.0.1.block2.proj.bias', 'online_model.model.downs.0.1.block2.norm.weight', 'online_model.model.downs.0.1.block2.norm.bias', 'online_model.model.downs.0.2.norm.g', 'online_model.model.downs.0.2.to_qkv.weight', 'online_model.model.downs.0.2.to_out.0.weight', 'online_model.model.downs.0.2.to_out.0.bias', 'online_model.model.downs.0.2.to_out.1.g', 'online_model.model.downs.0.3.1.weight', 'online_model.model.downs.0.3.1.bias', 'online_model.model.downs.1.0.mlp.1.weight', 'online_model.model.downs.1.0.mlp.1.bias', 'online_model.model.downs.1.0.block1.proj.weight', 'online_model.model.downs.1.0.block1.proj.bias', 'online_model.model.downs.1.0.block1.norm.weight', 'online_model.model.downs.1.0.block1.norm.bias', 'online_model.model.downs.1.0.block2.proj.weight', 'online_model.model.downs.1.0.block2.proj.bias', 'online_model.model.downs.1.0.block2.norm.weight', 'online_model.model.downs.1.0.block2.norm.bias', 'online_model.model.downs.1.1.mlp.1.weight', 'online_model.model.downs.1.1.mlp.1.bias', 'online_model.model.downs.1.1.block1.proj.weight', 'online_model.model.downs.1.1.block1.proj.bias', 'online_model.model.downs.1.1.block1.norm.weight', 'online_model.model.downs.1.1.block1.norm.bias', 'online_model.model.downs.1.1.block2.proj.weight', 'online_model.model.downs.1.1.block2.proj.bias', 'online_model.model.downs.1.1.block2.norm.weight', 'online_model.model.downs.1.1.block2.norm.bias', 'online_model.model.downs.1.2.norm.g', 'online_model.model.downs.1.2.to_qkv.weight', 'online_model.model.downs.1.2.to_out.0.weight', 'online_model.model.downs.1.2.to_out.0.bias', 'online_model.model.downs.1.2.to_out.1.g', 'online_model.model.downs.1.3.1.weight', 'online_model.model.downs.1.3.1.bias', 'online_model.model.downs.2.0.mlp.1.weight', 'online_model.model.downs.2.0.mlp.1.bias', 'online_model.model.downs.2.0.block1.proj.weight', 'online_model.model.downs.2.0.block1.proj.bias', 'online_model.model.downs.2.0.block1.norm.weight', 'online_model.model.downs.2.0.block1.norm.bias', 'online_model.model.downs.2.0.block2.proj.weight', 'online_model.model.downs.2.0.block2.proj.bias', 'online_model.model.downs.2.0.block2.norm.weight', 'online_model.model.downs.2.0.block2.norm.bias', 'online_model.model.downs.2.1.mlp.1.weight', 'online_model.model.downs.2.1.mlp.1.bias', 'online_model.model.downs.2.1.block1.proj.weight', 'online_model.model.downs.2.1.block1.proj.bias', 'online_model.model ...

# %%
# 这样加载会失败
diffusion.load_state_dict(ema_dict)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 diffusion.load_state_dict(ema_dict)                                                          │
# │   2                                                                                              │
# │                                                                                                  │
# │ d:\miniconda3\envs\pytorch\Lib\site-packages\torch\nn\modules\module.py:2041 in load_state_dict  │
# │                                                                                                  │
# │   2038 │   │   │   │   │   │   ', '.join('"{}"'.format(k) for k in missing_keys)))               │
# │   2039 │   │                                                                                     │
# │   2040 │   │   if len(error_msgs) > 0:                                                           │
# │ ❱ 2041 │   │   │   raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(     │
# │   2042 │   │   │   │   │   │   │      self.__class__.__name__, "\n\t".join(error_msgs)))         │
# │   2043 │   │   return _IncompatibleKeys(missing_keys, unexpected_keys)                           │
# │   2044                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Error(s) in loading state_dict for GaussianDiffusion:
#         Missing key(s) in state_dict: "betas", "alphas_cumprod", "alphas_cumprod_prev", "sqrt_alphas_cumprod",
# "sqrt_one_minus_alphas_cumprod", "log_one_minus_alphas_cumprod", "sqrt_recip_alphas_cumprod",
# "sqrt_recipm1_alphas_cumprod", "posterior_variance", "posterior_log_variance_clipped", "posterior_mean_coef1",
# "posterior_mean_coef2", "loss_weight", "model.init_conv.weight", "model.init_conv.bias", "model.time_mlp.1.weight",
# "model.time_mlp.1.bias", "model.time_mlp.3.weight", "model.time_mlp.3.bias", "model.downs.0.0.mlp.1.weight",
# "model.downs.0.0.mlp.1.bias", "model.downs.0.0.block1.proj.weight", "model.downs.0.0.block1.proj.bias",
# "model.downs.0.0.block1.norm.weight", "model.downs.0.0.block1.norm.bias", "model.downs.0.0.block2.proj.weight",
# "model.downs.0.0.block2.proj.bias", "model.downs.0.0.block2.norm.weight", "model.downs.0.0.block2.norm.bias",
# "model.downs.0.1.mlp.1.weight", "model.downs.0.1.mlp.1.bias", "model.downs.0.1.block1.proj.weight",
# "model.downs.0.1.block1.proj.bias", "model.downs.0.1.block1.norm.weight", "model.downs.0.1.block1.norm.bias",
# "model.downs.0.1.block2.proj.weight", "model.downs.0.1.block2.proj.bias", "model.downs.0.1.block2.norm.weight",
# "model.downs.0.1.block2.norm.bias", "model.downs.0.2.norm.g", "model.downs.0.2.to_qkv.weight",
# "model.downs.0.2.to_out.0.weight", "model.downs.0.2.to_out.0.bias", "model.downs.0.2.to_out.1.g",
# "model.downs.0.3.1.weight", "model.downs.0.3.1.bias", "model.downs.1.0.mlp.1.weight", "model.downs.1.0.mlp.1.bias",
# "model.downs.1.0.block1.proj.weight", "model.downs.1.0.block1.proj.bias", "model.downs.1.0.block1.norm.weight",
# "model.downs.1.0.block1.norm.bias", "model.downs.1.0.block2.proj.weight", "model.downs.1.0.block2.proj.bias",
# "model.downs.1.0.block2.norm.weight", "model.downs.1.0.block2.norm.bias", "model.downs.1.1.mlp.1.weight",
# "model.downs.1.1.mlp.1.bias", "model.downs.1.1.block1.proj.weight", "model.downs.1.1.block1.proj.bias",
# "model.downs.1.1.block1.norm.weight", "model.downs.1.1.block1.norm.bias", "model.downs.1.1.block2.proj.weight",
# "model.downs.1.1.block2.proj.bias", "model.downs.1.1.block2.norm.weight", "model.downs.1.1.block2.norm.bias",
# "model.downs.1.2.norm.g", "model.downs.1.2.to_qkv.weight", "model.downs.1.2.to_out.0.weight",
# "model.downs.1.2.to_out.0.bias", "model.downs.1.2.to_out.1.g", "model.downs.1.3.1.weight",
# "model.downs.1.3.1.bias", "model.downs.2.0.mlp.1.weight", "model.downs.2.0.mlp.1.bias",
# "model.downs.2.0.block1.proj.weight", "model.downs.2.0.block1.proj.bias", "model.downs.2.0.block1.norm.weight",
# "model.downs.2.0.block1.norm.bias", "model.downs.2.0.block2.proj.weight", "model.downs.2.0.block2.proj.bias",
# "model.downs.2.0.block2.norm.weight", "model.downs.2.0.block2.norm.bias", "model.downs.2.1.mlp.1.weight",
# "model.downs.2.1.mlp.1.bias", "model.downs.2.1.block1.proj.weight", "model.downs.2.1.block1.proj.bias",
# "model.downs.2.1.block1.norm.weight", "model.downs.2.1.block1.norm.bias", "model.downs.2.1.block2.proj.weight",
# "model.downs.2.1.block2.proj.bias", "model.downs.2.1.block2.norm.weight", "model.downs.2.1.block2.norm.bias",
# "model.downs.2.2.norm.g", "model.downs.2.2.to_qkv.weight", "model.downs.2.2.to_out.0.weight",
# "model.downs.2.2.to_out.0.bias", "model.downs.2.2.to_out.1.g", "model.downs.2.3.1.weight",
# "model.downs.2.3.1.bias", "model.downs.3.0.mlp.1.weight", "model.downs.3.0.mlp.1.bias",
# "model.downs.3.0.block1.proj.weight", "model.downs.3.0.block1.proj.bias", "model.downs.3.0.block1.norm.weight",
# "model.downs.3.0.block1.norm.bias", "model.downs.3.0.block2.proj.weight", "model.downs.3.0.block2.proj.bias",
# "model.downs.3.0.block2.norm.weight", "model.downs.3.0.block2.norm.bias", "model.downs.3.1.mlp.1.weight",
# "model.downs.3.1.mlp.1.bias", "model.downs.3.1.block1.proj.weight", "model.downs.3.1.block1.proj.bias",
# "model.downs.3.1.block1.norm.weight", "model.downs.3.1.block1.norm.bias", "model.downs.3.1.block2.proj.weight",
# "model.downs.3.1.block2.proj.bias", "model.downs.3.1.block2.norm.weight", "model.downs.3.1.block2.norm.bias",
# "model.downs.3.2.norm.g", "model.downs.3.2.to_qkv.weight", "model.downs.3.2.to_out.weight",
# "model.downs.3.2.to_out.bias", "model.downs.3.3.weight", "model.downs.3.3.bias", "model.ups.0.0.mlp.1.weight",
# "model.ups.0.0.mlp.1.bias", "model.ups.0.0.block1.proj.weight", "model.ups.0.0.block1.proj.bias",
# "model.ups.0.0.block1.norm.weight", "model.ups.0.0.block1.norm.bias", "model.ups.0.0.block2.proj.weight",
# "model.ups.0.0.block2.proj.bias", "model.ups.0.0.block2.norm.weight", "model.ups.0.0.block2.norm.bias",
# "model.ups.0.0.res_conv.weight", "model.ups.0.0.res_conv.bias", "model.ups.0.1.mlp.1.weight",
# "model.ups.0.1.mlp.1.bias", "model.ups.0.1.block1.proj.weight", "model.ups.0.1.block1.proj.bias",
# "model.ups.0.1.block1.norm.weight", "model.ups.0.1.block1.norm.bias", "model.ups.0.1.block2.proj.weight",
# "model.ups.0.1.block2.proj.bias", "model.ups.0.1.block2.norm.weight", "model.ups.0.1.block2.norm.bias",
# "model.ups.0.1.res_conv.weight", "model.ups.0.1.res_conv.bias", "model.ups.0.2.norm.g",
# "model.ups.0.2.to_qkv.weight", "model.ups.0.2.to_out.weight", "model.ups.0.2.to_out.bias",
# "model.ups.0.3.1.weight", "model.ups.0.3.1.bias", "model.ups.1.0.mlp.1.weight", "model.ups.1.0.mlp.1.bias",
# "model.ups.1.0.block1.proj.weight", "model.ups.1.0.block1.proj.bias", "model.ups.1.0.block1.norm.weight",
# "model.ups.1.0.block1.norm.bias", "model.ups.1.0.block2.proj.weight", "model.ups.1.0.block2.proj.bias",
# "model.ups.1.0.block2.norm.weight", "model.ups.1.0.block2.norm.bias", "model.ups.1.0.res_conv.weight",
# "model.ups.1.0.res_conv.bias", "model.ups.1.1.mlp.1.weight", "model.ups.1.1.mlp.1.bias",
# "model.ups.1.1.block1.proj.weight", "model.ups.1.1.block1.proj.bias", "model.ups.1.1.block1.norm.weight",
# "model.ups.1.1.block1.norm.bias", "model.ups.1.1.block2.proj.weight", "model.ups.1.1.block2.proj.bias",
# "model.ups.1.1.block2.norm.weight", "model.ups.1.1.block2.norm.bias", "model.ups.1.1.res_conv.weight",
# "model.ups.1.1.res_conv.bias", "model.ups.1.2.norm.g", "model.ups.1.2.to_qkv.weight",
# "model.ups.1.2.to_out.0.weight", "model.ups.1.2.to_out.0.bias", "model.ups.1.2.to_out.1.g",
# "model.ups.1.3.1.weight", "model.ups.1.3.1.bias", "model.ups.2.0.mlp.1.weight", "model.ups.2.0.mlp.1.bias",
# "model.ups.2.0.block1.proj.weight", "model.ups.2.0.block1.proj.bias", "model.ups.2.0.block1.norm.weight",
# "model.ups.2.0.block1.norm.bias", "model.ups.2.0.block2.proj.weight", "model.ups.2.0.block2.proj.bias",
# "model.ups.2.0.block2.norm.weight", "model.ups.2.0.block2.norm.bias", "model.ups.2.0.res_conv.weight",
# "model.ups.2.0.res_conv.bias", "model.ups.2.1.mlp.1.weight", "model.ups.2.1.mlp.1.bias",
# "model.ups.2.1.block1.proj.weight", "model.ups.2.1.block1.proj.bias", "model.ups.2.1.block1.norm.weight",
# "model.ups.2.1.block1.norm.bias", "model.ups.2.1.block2.proj.weight", "model.ups.2.1.block2.proj.bias",
# "model.ups.2.1.block2.norm.weight", "model.ups.2.1.block2.norm.bias", "model.ups.2.1.res_conv.weight",
# "model.ups.2.1.res_conv.bias", "model.ups.2.2.norm.g", "model.ups.2.2.to_qkv.weight",
# "model.ups.2.2.to_out.0.weight", "model.ups.2.2.to_out.0.bias", "model.ups.2.2.to_out.1.g",
# "model.ups.2.3.1.weight", "model.ups.2.3.1.bias", "model.ups.3.0.mlp.1.weight", "model.ups.3.0.mlp.1.bias",
# "model.ups.3.0.block1.proj.weight", "model.ups.3.0.block1.proj.bias", "model.ups.3.0.block1.norm.weight",
# "model.ups.3.0.block1.norm.bias", "model.ups.3.0.block2.proj.weight", "model.ups.3.0.block2.proj.bias",
# "model.ups.3.0.block2.norm.weight", "model.ups.3.0.block2.norm.bias", "model.ups.3.0.res_conv.weight",
# "model.ups.3.0.res_conv.bias", "model.ups.3.1.mlp.1.weight", "model.ups.3.1.mlp.1.bias",
# "model.ups.3.1.block1.proj.weight", "model.ups.3.1.block1.proj.bias", "model.ups.3.1.block1.norm.weight",
# "model.ups.3.1.block1.norm.bias", "model.ups.3.1.block2.proj.weight", "model.ups.3.1.block2.proj.bias",
# "model.ups.3.1.block2.norm.weight", "model.ups.3.1.block2.norm.bias", "model.ups.3.1.res_conv.weight",
# "model.ups.3.1.res_conv.bias", "model.ups.3.2.norm.g", "model.ups.3.2.to_qkv.weight",
# "model.ups.3.2.to_out.0.weight", "model.ups.3.2.to_out.0.bias", "model.ups.3.2.to_out.1.g", "model.ups.3.3.weight",
# "model.ups.3.3.bias", "model.mid_block1.mlp.1.weight", "model.mid_block1.mlp.1.bias",
# "model.mid_block1.block1.proj.weight", "model.mid_block1.block1.proj.bias", "model.mid_block1.block1.norm.weight",
# "model.mid_block1.block1.norm.bias", "model.mid_block1.block2.proj.weight", "model.mid_block1.block2.proj.bias",
# "model.mid_block1.block2.norm.weight", "model.mid_block1.block2.norm.bias", "model.mid_attn.norm.g",
# "model.mid_attn.to_qkv.weight", "model.mid_attn.to_out.weight", "model.mid_attn.to_out.bias",
# "model.mid_block2.mlp.1.weight", "model.mid_block2.mlp.1.bias", "model.mid_block2.block1.proj.weight",
# "model.mid_block2.block1.proj.bias", "model.mid_block2.block1.norm.weight", "model.mid_block2.block1.norm.bias",
# "model.mid_block2.block2.proj.weight", "model.mid_block2.block2.proj.bias", "model.mid_block2.block2.norm.weight",
# "model.mid_block2.block2.norm.bias", "model.final_res_block.mlp.1.weight", "model.final_res_block.mlp.1.bias",
# "model.final_res_block.block1.proj.weight", "model.final_res_block.block1.proj.bias",
# "model.final_res_block.block1.norm.weight", "model.final_res_block.block1.norm.bias",
# "model.final_res_block.block2.proj.weight", "model.final_res_block.block2.proj.bias",
# "model.final_res_block.block2.norm.weight", "model.final_res_block.block2.norm.bias",
# "model.final_res_block.res_conv.weight", "model.final_res_block.res_conv.bias", "model.final_conv.weight",
# "model.final_conv.bias".
#         Unexpected key(s) in state_dict: "initted", "step", "online_model.betas", "online_model.alphas_cumprod",
# "online_model.alphas_cumprod_prev", "online_model.sqrt_alphas_cumprod",
# "online_model.sqrt_one_minus_alphas_cumprod", "online_model.log_one_minus_alphas_cumprod",
# "online_model.sqrt_recip_alphas_cumprod", "online_model.sqrt_recipm1_alphas_cumprod",
# "online_model.posterior_variance", "online_model.posterior_log_variance_clipped",
# "online_model.posterior_mean_coef1", "online_model.posterior_mean_coef2", "online_model.loss_weight",
# "online_model.model.init_conv.weight", "online_model.model.init_conv.bias", "online_model.model.time_mlp.1.weight",
# "online_model.model.time_mlp.1.bias", "online_model.model.time_mlp.3.weight", "online_model.model.time_mlp.3.bias",
# "online_model.model.downs.0.0.mlp.1.weight", "online_model.model.downs.0.0.mlp.1.bias",
# "online_model.model.downs.0.0.block1.proj.weight", "online_model.model.downs.0.0.block1.proj.bias",
# "online_model.model.downs.0.0.block1.norm.weight", "online_model.model.downs.0.0.block1.norm.bias",
# "online_model.model.downs.0.0.block2.proj.weight", "online_model.model.downs.0.0.block2.proj.bias",
# "online_model.model.downs.0.0.block2.norm.weight", "online_model.model.downs.0.0.block2.norm.bias",
# "online_model.model.downs.0.1.mlp.1.weight", "online_model.model.downs.0.1.mlp.1.bias",
# "online_model.model.downs.0.1.block1.proj.weight", "online_model.model.downs.0.1.block1.proj.bias",
# "online_model.model.downs.0.1.block1.norm.weight", "online_model.model.downs.0.1.block1.norm.bias",
# "online_model.model.downs.0.1.block2.proj.weight", "online_model.model.downs.0.1.block2.proj.bias",
# "online_model.model.downs.0.1.block2.norm.weight", "online_model.model.downs.0.1.block2.norm.bias",
# "online_model.model.downs.0.2.norm.g", "online_model.model.downs.0.2.to_qkv.weight",
# "online_model.model.downs.0.2.to_out.0.weight", "online_model.model.downs.0.2.to_out.0.bias",
# "online_model.model.downs.0.2.to_out.1.g", "online_model.model.downs.0.3.1.weight",
# "online_model.model.downs.0.3.1.bias", "online_model.model.downs.1.0.mlp.1.weight",
# "online_model.model.downs.1.0.mlp.1.bias", "online_model.model.downs.1.0.block1.proj.weight",
# "online_model.model.downs.1.0.block1.proj.bias", "online_model.model.downs.1.0.block1.norm.weight",
# "online_model.model.downs.1.0.block1.norm.bias", "online_model.model.downs.1.0.block2.proj.weight",
# "online_model.model.downs.1.0.block2.proj.bias", "online_model.model.downs.1.0.block2.norm.weight",
# "online_model.model.downs.1.0.block2.norm.bias", "online_model.model.downs.1.1.mlp.1.weight",
# "online_model.model.downs.1.1.mlp.1.bias", "online_model.model.downs.1.1.block1.proj.weight",
# "online_model.model.downs.1.1.block1.proj.bias", "online_model.model.downs.1.1.block1.norm.weight",
# "online_model.model.downs.1.1.block1.norm.bias", "online_model.model.downs.1.1.block2.proj.weight",
# "online_model.model.downs.1.1.block2.proj.bias", "online_model.model.downs.1.1.block2.norm.weight",
# "online_model.model.downs.1.1.block2.norm.bias", "online_model.model.downs.1.2.norm.g",
# "online_model.model.downs.1.2.to_qkv.weight", "online_model.model.downs.1.2.to_out.0.weight",
# "online_model.model.downs.1.2.to_out.0.bias", "online_model.model.downs.1.2.to_out.1.g",
# "online_model.model.downs.1.3.1.weight", "online_model.model.downs.1.3.1.bias",
# "online_model.model.downs.2.0.mlp.1.weight", "online_model.model.downs.2.0.mlp.1.bias",
# "online_model.model.downs.2.0.block1.proj.weight", "online_model.model.downs.2.0.block1.proj.bias",
# "online_model.model.downs.2.0.block1.norm.weight", "online_model.model.downs.2.0.block1.norm.bias",
# "online_model.model.downs.2.0.block2.proj.weight", "online_model.model.downs.2.0.block2.proj.bias",
# "online_model.model.downs.2.0.block2.norm.weight", "online_model.model.downs.2.0.block2.norm.bias",
# "online_model.model.downs.2.1.mlp.1.weight", "online_model.model.downs.2.1.mlp.1.bias",
# "online_model.model.downs.2.1.block1.proj.weight", "online_model.model.downs.2.1.block1.proj.bias",
# "online_model.model.downs.2.1.block1.norm.weight", "online_model.model.downs.2.1.block1.norm.bias",
# "online_model.model.downs.2.1.block2.proj.weight", "online_model.model.downs.2.1.block2.proj.bias",
# "online_model.model.downs.2.1.block2.norm.weight", "online_model.model.downs.2.1.block2.norm.bias",
# "online_model.model.downs.2.2.norm.g", "online_model.model.downs.2.2.to_qkv.weight",
# "online_model.model.downs.2.2.to_out.0.weight", "online_model.model.downs.2.2.to_out.0.bias",
# "online_model.model.downs.2.2.to_out.1.g", "online_model.model.downs.2.3.1.weight",
# "online_model.model.downs.2.3.1.bias", "online_model.model.downs.3.0.mlp.1.weight",
# "online_model.model.downs.3.0.mlp.1.bias", "online_model.model.downs.3.0.block1.proj.weight",
# "online_model.model.downs.3.0.block1.proj.bias", "online_model.model.downs.3.0.block1.norm.weight",
# "online_model.model.downs.3.0.block1.norm.bias", "online_model.model.downs.3.0.block2.proj.weight",
# "online_model.model.downs.3.0.block2.proj.bias", "online_model.model.downs.3.0.block2.norm.weight",
# "online_model.model.downs.3.0.block2.norm.bias", "online_model.model.downs.3.1.mlp.1.weight",
# "online_model.model.downs.3.1.mlp.1.bias", "online_model.model.downs.3.1.block1.proj.weight",
# "online_model.model.downs.3.1.block1.proj.bias", "online_model.model.downs.3.1.block1.norm.weight",
# "online_model.model.downs.3.1.block1.norm.bias", "online_model.model.downs.3.1.block2.proj.weight",
# "online_model.model.downs.3.1.block2.proj.bias", "online_model.model.downs.3.1.block2.norm.weight",
# "online_model.model.downs.3.1.block2.norm.bias", "online_model.model.downs.3.2.norm.g",
# "online_model.model.downs.3.2.to_qkv.weight", "online_model.model.downs.3.2.to_out.weight",
# "online_model.model.downs.3.2.to_out.bias", "online_model.model.downs.3.3.weight",
# "online_model.model.downs.3.3.bias", "online_model.model.ups.0.0.mlp.1.weight",
# "online_model.model.ups.0.0.mlp.1.bias", "online_model.model.ups.0.0.block1.proj.weight",
# "online_model.model.ups.0.0.block1.proj.bias", "online_model.model.ups.0.0.block1.norm.weight",
# "online_model.model.ups.0.0.block1.norm.bias", "online_model.model.ups.0.0.block2.proj.weight",
# "online_model.model.ups.0.0.block2.proj.bias", "online_model.model.ups.0.0.block2.norm.weight",
# "online_model.model.ups.0.0.block2.norm.bias", "online_model.model.ups.0.0.res_conv.weight",
# "online_model.model.ups.0.0.res_conv.bias", "online_model.model.ups.0.1.mlp.1.weight",
# "online_model.model.ups.0.1.mlp.1.bias", "online_model.model.ups.0.1.block1.proj.weight",
# "online_model.model.ups.0.1.block1.proj.bias", "online_model.model.ups.0.1.block1.norm.weight",
# "online_model.model.ups.0.1.block1.norm.bias", "online_model.model.ups.0.1.block2.proj.weight",
# "online_model.model.ups.0.1.block2.proj.bias", "online_model.model.ups.0.1.block2.norm.weight",
# "online_model.model.ups.0.1.block2.norm.bias", "online_model.model.ups.0.1.res_conv.weight",
# "online_model.model.ups.0.1.res_conv.bias", "online_model.model.ups.0.2.norm.g",
# "online_model.model.ups.0.2.to_qkv.weight", "online_model.model.ups.0.2.to_out.weight",
# "online_model.model.ups.0.2.to_out.bias", "online_model.model.ups.0.3.1.weight",
# "online_model.model.ups.0.3.1.bias", "online_model.model.ups.1.0.mlp.1.weight",
# "online_model.model.ups.1.0.mlp.1.bias", "online_model.model.ups.1.0.block1.proj.weight",
# "online_model.model.ups.1.0.block1.proj.bias", "online_model.model.ups.1.0.block1.norm.weight",
# "online_model.model.ups.1.0.block1.norm.bias", "online_model.model.ups.1.0.block2.proj.weight",
# "online_model.model.ups.1.0.block2.proj.bias", "online_model.model.ups.1.0.block2.norm.weight",
# "online_model.model.ups.1.0.block2.norm.bias", "online_model.model.ups.1.0.res_conv.weight",
# "online_model.model.ups.1.0.res_conv.bias", "online_model.model.ups.1.1.mlp.1.weight",
# "online_model.model.ups.1.1.mlp.1.bias", "online_model.model.ups.1.1.block1.proj.weight",
# "online_model.model.ups.1.1.block1.proj.bias", "online_model.model.ups.1.1.block1.norm.weight",
# "online_model.model.ups.1.1.block1.norm.bias", "online_model.model.ups.1.1.block2.proj.weight",
# "online_model.model.ups.1.1.block2.proj.bias", "online_model.model.ups.1.1.block2.norm.weight",
# "online_model.model.ups.1.1.block2.norm.bias", "online_model.model.ups.1.1.res_conv.weight",
# "online_model.model.ups.1.1.res_conv.bias", "online_model.model.ups.1.2.norm.g",
# "online_model.model.ups.1.2.to_qkv.weight", "online_model.model.ups.1.2.to_out.0.weight",
# "online_model.model.ups.1.2.to_out.0.bias", "online_model.model.ups.1.2.to_out.1.g",
# "online_model.model.ups.1.3.1.weight", "online_model.model.ups.1.3.1.bias",
# "online_model.model.ups.2.0.mlp.1.weight", "online_model.model.ups.2.0.mlp.1.bias",
# "online_model.model.ups.2.0.block1.proj.weight", "online_model.model.ups.2.0.block1.proj.bias",
# "online_model.model.ups.2.0.block1.norm.weight", "online_model.model.ups.2.0.block1.norm.bias",
# "online_model.model.ups.2.0.block2.proj.weight", "online_model.model.ups.2.0.block2.proj.bias",
# "online_model.model.ups.2.0.block2.norm.weight", "online_model.model.ups.2.0.block2.norm.bias",
# "online_model.model.ups.2.0.res_conv.weight", "online_model.model.ups.2.0.res_conv.bias",
# "online_model.model.ups.2.1.mlp.1.weight", "online_model.model.ups.2.1.mlp.1.bias",
# "online_model.model.ups.2.1.block1.proj.weight", "online_model.model.ups.2.1.block1.proj.bias",
# "online_model.model.ups.2.1.block1.norm.weight", "online_model.model.ups.2.1.block1.norm.bias",
# "online_model.model.ups.2.1.block2.proj.weight", "online_model.model.ups.2.1.block2.proj.bias",
# "online_model.model.ups.2.1.block2.norm.weight", "online_model.model.ups.2.1.block2.norm.bias",
# "online_model.model.ups.2.1.res_conv.weight", "online_model.model.ups.2.1.res_conv.bias",
# "online_model.model.ups.2.2.norm.g", "online_model.model.ups.2.2.to_qkv.weight",
# "online_model.model.ups.2.2.to_out.0.weight", "online_model.model.ups.2.2.to_out.0.bias",
# "online_model.model.ups.2.2.to_out.1.g", "online_model.model.ups.2.3.1.weight",
# "online_model.model.ups.2.3.1.bias", "online_model.model.ups.3.0.mlp.1.weight",
# "online_model.model.ups.3.0.mlp.1.bias", "online_model.model.ups.3.0.block1.proj.weight",
# "online_model.model.ups.3.0.block1.proj.bias", "online_model.model.ups.3.0.block1.norm.weight",
# "online_model.model.ups.3.0.block1.norm.bias", "online_model.model.ups.3.0.block2.proj.weight",
# "online_model.model.ups.3.0.block2.proj.bias", "online_model.model.ups.3.0.block2.norm.weight",
# "online_model.model.ups.3.0.block2.norm.bias", "online_model.model.ups.3.0.res_conv.weight",
# "online_model.model.ups.3.0.res_conv.bias", "online_model.model.ups.3.1.mlp.1.weight",
# "online_model.model.ups.3.1.mlp.1.bias", "online_model.model.ups.3.1.block1.proj.weight",
# "online_model.model.ups.3.1.block1.proj.bias", "online_model.model.ups.3.1.block1.norm.weight",
# "online_model.model.ups.3.1.block1.norm.bias", "online_model.model.ups.3.1.block2.proj.weight",
# "online_model.model.ups.3.1.block2.proj.bias", "online_model.model.ups.3.1.block2.norm.weight",
# "online_model.model.ups.3.1.block2.norm.bias", "online_model.model.ups.3.1.res_conv.weight",
# "online_model.model.ups.3.1.res_conv.bias", "online_model.model.ups.3.2.norm.g",
# "online_model.model.ups.3.2.to_qkv.weight", "online_model.model.ups.3.2.to_out.0.weight",
# "online_model.model.ups.3.2.to_out.0.bias", "online_model.model.ups.3.2.to_out.1.g",
# "online_model.model.ups.3.3.weight", "online_model.model.ups.3.3.bias",
# "online_model.model.mid_block1.mlp.1.weight", "online_model.model.mid_block1.mlp.1.bias",
# "online_model.model.mid_block1.block1.proj.weight", "online_model.model.mid_block1.block1.proj.bias",
# "online_model.model.mid_block1.block1.norm.weight", "online_model.model.mid_block1.block1.norm.bias",
# "online_model.model.mid_block1.block2.proj.weight", "online_model.model.mid_block1.block2.proj.bias",
# "online_model.model.mid_block1.block2.norm.weight", "online_model.model.mid_block1.block2.norm.bias",
# "online_model.model.mid_attn.norm.g", "online_model.model.mid_attn.to_qkv.weight",
# "online_model.model.mid_attn.to_out.weight", "online_model.model.mid_attn.to_out.bias",
# "online_model.model.mid_block2.mlp.1.weight", "online_model.model.mid_block2.mlp.1.bias",
# "online_model.model.mid_block2.block1.proj.weight", "online_model.model.mid_block2.block1.proj.bias",
# "online_model.model.mid_block2.block1.norm.weight", "online_model.model.mid_block2.block1.norm.bias",
# "online_model.model.mid_block2.block2.proj.weight", "online_model.model.mid_block2.block2.proj.bias",
# "online_model.model.mid_block2.block2.norm.weight", "online_model.model.mid_block2.block2.norm.bias",
# "online_model.model.final_res_block.mlp.1.weight", "online_model.model.final_res_block.mlp.1.bias",
# "online_model.model.final_res_block.block1.proj.weight", "online_model.model.final_res_block.block1.proj.bias",
# "online_model.model.final_res_block.block1.norm.weight", "online_model.model.final_res_block.block1.norm.bias",
# "online_model.model.final_res_block.block2.proj.weight", "online_model.model.final_res_block.block2.proj.bias",
# "online_model.model.final_res_block.block2.norm.weight", "online_model.model.final_res_block.block2.norm.bias",
# "online_model.model.final_res_block.res_conv.weight", "online_model.model.final_res_block.res_conv.bias",
# "online_model.model.final_conv.weight", "online_model.model.final_conv.bias", "ema_model.betas",
# "ema_model.alphas_cumprod", "ema_model.alphas_cumprod_prev", "ema_model.sqrt_alphas_cumprod",
# "ema_model.sqrt_one_minus_alphas_cumprod", "ema_model.log_one_minus_alphas_cumprod",
# "ema_model.sqrt_recip_alphas_cumprod", "ema_model.sqrt_recipm1_alphas_cumprod", "ema_model.posterior_variance",
# "ema_model.posterior_log_variance_clipped", "ema_model.posterior_mean_coef1", "ema_model.posterior_mean_coef2",
# "ema_model.loss_weight", "ema_model.model.init_conv.weight", "ema_model.model.init_conv.bias",
# "ema_model.model.time_mlp.1.weight", "ema_model.model.time_mlp.1.bias", "ema_model.model.time_mlp.3.weight",
# "ema_model.model.time_mlp.3.bias", "ema_model.model.downs.0.0.mlp.1.weight",
# "ema_model.model.downs.0.0.mlp.1.bias", "ema_model.model.downs.0.0.block1.proj.weight",
# "ema_model.model.downs.0.0.block1.proj.bias", "ema_model.model.downs.0.0.block1.norm.weight",
# "ema_model.model.downs.0.0.block1.norm.bias", "ema_model.model.downs.0.0.block2.proj.weight",
# "ema_model.model.downs.0.0.block2.proj.bias", "ema_model.model.downs.0.0.block2.norm.weight",
# "ema_model.model.downs.0.0.block2.norm.bias", "ema_model.model.downs.0.1.mlp.1.weight",
# "ema_model.model.downs.0.1.mlp.1.bias", "ema_model.model.downs.0.1.block1.proj.weight",
# "ema_model.model.downs.0.1.block1.proj.bias", "ema_model.model.downs.0.1.block1.norm.weight",
# "ema_model.model.downs.0.1.block1.norm.bias", "ema_model.model.downs.0.1.block2.proj.weight",
# "ema_model.model.downs.0.1.block2.proj.bias", "ema_model.model.downs.0.1.block2.norm.weight",
# "ema_model.model.downs.0.1.block2.norm.bias", "ema_model.model.downs.0.2.norm.g",
# "ema_model.model.downs.0.2.to_qkv.weight", "ema_model.model.downs.0.2.to_out.0.weight",
# "ema_model.model.downs.0.2.to_out.0.bias", "ema_model.model.downs.0.2.to_out.1.g",
# "ema_model.model.downs.0.3.1.weight", "ema_model.model.downs.0.3.1.bias", "ema_model.model.downs.1.0.mlp.1.weight",
# "ema_model.model.downs.1.0.mlp.1.bias", "ema_model.model.downs.1.0.block1.proj.weight",
# "ema_model.model.downs.1.0.block1.proj.bias", "ema_model.model.downs.1.0.block1.norm.weight",
# "ema_model.model.downs.1.0.block1.norm.bias", "ema_model.model.downs.1.0.block2.proj.weight",
# "ema_model.model.downs.1.0.block2.proj.bias", "ema_model.model.downs.1.0.block2.norm.weight",
# "ema_model.model.downs.1.0.block2.norm.bias", "ema_model.model.downs.1.1.mlp.1.weight",
# "ema_model.model.downs.1.1.mlp.1.bias", "ema_model.model.downs.1.1.block1.proj.weight",
# "ema_model.model.downs.1.1.block1.proj.bias", "ema_model.model.downs.1.1.block1.norm.weight",
# "ema_model.model.downs.1.1.block1.norm.bias", "ema_model.model.downs.1.1.block2.proj.weight",
# "ema_model.model.downs.1.1.block2.proj.bias", "ema_model.model.downs.1.1.block2.norm.weight",
# "ema_model.model.downs.1.1.block2.norm.bias", "ema_model.model.downs.1.2.norm.g",
# "ema_model.model.downs.1.2.to_qkv.weight", "ema_model.model.downs.1.2.to_out.0.weight",
# "ema_model.model.downs.1.2.to_out.0.bias", "ema_model.model.downs.1.2.to_out.1.g",
# "ema_model.model.downs.1.3.1.weight", "ema_model.model.downs.1.3.1.bias", "ema_model.model.downs.2.0.mlp.1.weight",
# "ema_model.model.downs.2.0.mlp.1.bias", "ema_model.model.downs.2.0.block1.proj.weight",
# "ema_model.model.downs.2.0.block1.proj.bias", "ema_model.model.downs.2.0.block1.norm.weight",
# "ema_model.model.downs.2.0.block1.norm.bias", "ema_model.model.downs.2.0.block2.proj.weight",
# "ema_model.model.downs.2.0.block2.proj.bias", "ema_model.model.downs.2.0.block2.norm.weight",
# "ema_model.model.downs.2.0.block2.norm.bias", "ema_model.model.downs.2.1.mlp.1.weight",
# "ema_model.model.downs.2.1.mlp.1.bias", "ema_model.model.downs.2.1.block1.proj.weight",
# "ema_model.model.downs.2.1.block1.proj.bias", "ema_model.model.downs.2.1.block1.norm.weight",
# "ema_model.model.downs.2.1.block1.norm.bias", "ema_model.model.downs.2.1.block2.proj.weight",
# "ema_model.model.downs.2.1.block2.proj.bias", "ema_model.model.downs.2.1.block2.norm.weight",
# "ema_model.model.downs.2.1.block2.norm.bias", "ema_model.model.downs.2.2.norm.g",
# "ema_model.model.downs.2.2.to_qkv.weight", "ema_model.model.downs.2.2.to_out.0.weight",
# "ema_model.model.downs.2.2.to_out.0.bias", "ema_model.model.downs.2.2.to_out.1.g",
# "ema_model.model.downs.2.3.1.weight", "ema_model.model.downs.2.3.1.bias", "ema_model.model.downs.3.0.mlp.1.weight",
# "ema_model.model.downs.3.0.mlp.1.bias", "ema_model.model.downs.3.0.block1.proj.weight",
# "ema_model.model.downs.3.0.block1.proj.bias", "ema_model.model.downs.3.0.block1.norm.weight",
# "ema_model.model.downs.3.0.block1.norm.bias", "ema_model.model.downs.3.0.block2.proj.weight",
# "ema_model.model.downs.3.0.block2.proj.bias", "ema_model.model.downs.3.0.block2.norm.weight",
# "ema_model.model.downs.3.0.block2.norm.bias", "ema_model.model.downs.3.1.mlp.1.weight",
# "ema_model.model.downs.3.1.mlp.1.bias", "ema_model.model.downs.3.1.block1.proj.weight",
# "ema_model.model.downs.3.1.block1.proj.bias", "ema_model.model.downs.3.1.block1.norm.weight",
# "ema_model.model.downs.3.1.block1.norm.bias", "ema_model.model.downs.3.1.block2.proj.weight",
# "ema_model.model.downs.3.1.block2.proj.bias", "ema_model.model.downs.3.1.block2.norm.weight",
# "ema_model.model.downs.3.1.block2.norm.bias", "ema_model.model.downs.3.2.norm.g",
# "ema_model.model.downs.3.2.to_qkv.weight", "ema_model.model.downs.3.2.to_out.weight",
# "ema_model.model.downs.3.2.to_out.bias", "ema_model.model.downs.3.3.weight", "ema_model.model.downs.3.3.bias",
# "ema_model.model.ups.0.0.mlp.1.weight", "ema_model.model.ups.0.0.mlp.1.bias",
# "ema_model.model.ups.0.0.block1.proj.weight", "ema_model.model.ups.0.0.block1.proj.bias",
# "ema_model.model.ups.0.0.block1.norm.weight", "ema_model.model.ups.0.0.block1.norm.bias",
# "ema_model.model.ups.0.0.block2.proj.weight", "ema_model.model.ups.0.0.block2.proj.bias",
# "ema_model.model.ups.0.0.block2.norm.weight", "ema_model.model.ups.0.0.block2.norm.bias",
# "ema_model.model.ups.0.0.res_conv.weight", "ema_model.model.ups.0.0.res_conv.bias",
# "ema_model.model.ups.0.1.mlp.1.weight", "ema_model.model.ups.0.1.mlp.1.bias",
# "ema_model.model.ups.0.1.block1.proj.weight", "ema_model.model.ups.0.1.block1.proj.bias",
# "ema_model.model.ups.0.1.block1.norm.weight", "ema_model.model.ups.0.1.block1.norm.bias",
# "ema_model.model.ups.0.1.block2.proj.weight", "ema_model.model.ups.0.1.block2.proj.bias",
# "ema_model.model.ups.0.1.block2.norm.weight", "ema_model.model.ups.0.1.block2.norm.bias",
# "ema_model.model.ups.0.1.res_conv.weight", "ema_model.model.ups.0.1.res_conv.bias",
# "ema_model.model.ups.0.2.norm.g", "ema_model.model.ups.0.2.to_qkv.weight", "ema_model.model.ups.0.2.to_out.weight",
# "ema_model.model.ups.0.2.to_out.bias", "ema_model.model.ups.0.3.1.weight", "ema_model.model.ups.0.3.1.bias",
# "ema_model.model.ups.1.0.mlp.1.weight", "ema_model.model.ups.1.0.mlp.1.bias",
# "ema_model.model.ups.1.0.block1.proj.weight", "ema_model.model.ups.1.0.block1.proj.bias",
# "ema_model.model.ups.1.0.block1.norm.weight", "ema_model.model.ups.1.0.block1.norm.bias",
# "ema_model.model.ups.1.0.block2.proj.weight", "ema_model.model.ups.1.0.block2.proj.bias",
# "ema_model.model.ups.1.0.block2.norm.weight", "ema_model.model.ups.1.0.block2.norm.bias",
# "ema_model.model.ups.1.0.res_conv.weight", "ema_model.model.ups.1.0.res_conv.bias",
# "ema_model.model.ups.1.1.mlp.1.weight", "ema_model.model.ups.1.1.mlp.1.bias",
# "ema_model.model.ups.1.1.block1.proj.weight", "ema_model.model.ups.1.1.block1.proj.bias",
# "ema_model.model.ups.1.1.block1.norm.weight", "ema_model.model.ups.1.1.block1.norm.bias",
# "ema_model.model.ups.1.1.block2.proj.weight", "ema_model.model.ups.1.1.block2.proj.bias",
# "ema_model.model.ups.1.1.block2.norm.weight", "ema_model.model.ups.1.1.block2.norm.bias",
# "ema_model.model.ups.1.1.res_conv.weight", "ema_model.model.ups.1.1.res_conv.bias",
# "ema_model.model.ups.1.2.norm.g", "ema_model.model.ups.1.2.to_qkv.weight",
# "ema_model.model.ups.1.2.to_out.0.weight", "ema_model.model.ups.1.2.to_out.0.bias",
# "ema_model.model.ups.1.2.to_out.1.g", "ema_model.model.ups.1.3.1.weight", "ema_model.model.ups.1.3.1.bias",
# "ema_model.model.ups.2.0.mlp.1.weight", "ema_model.model.ups.2.0.mlp.1.bias",
# "ema_model.model.ups.2.0.block1.proj.weight", "ema_model.model.ups.2.0.block1.proj.bias",
# "ema_model.model.ups.2.0.block1.norm.weight", "ema_model.model.ups.2.0.block1.norm.bias",
# "ema_model.model.ups.2.0.block2.proj.weight", "ema_model.model.ups.2.0.block2.proj.bias",
# "ema_model.model.ups.2.0.block2.norm.weight", "ema_model.model.ups.2.0.block2.norm.bias",
# "ema_model.model.ups.2.0.res_conv.weight", "ema_model.model.ups.2.0.res_conv.bias",
# "ema_model.model.ups.2.1.mlp.1.weight", "ema_model.model.ups.2.1.mlp.1.bias",
# "ema_model.model.ups.2.1.block1.proj.weight", "ema_model.model.ups.2.1.block1.proj.bias",
# "ema_model.model.ups.2.1.block1.norm.weight", "ema_model.model.ups.2.1.block1.norm.bias",
# "ema_model.model.ups.2.1.block2.proj.weight", "ema_model.model.ups.2.1.block2.proj.bias",
# "ema_model.model.ups.2.1.block2.norm.weight", "ema_model.model.ups.2.1.block2.norm.bias",
# "ema_model.model.ups.2.1.res_conv.weight", "ema_model.model.ups.2.1.res_conv.bias",
# "ema_model.model.ups.2.2.norm.g", "ema_model.model.ups.2.2.to_qkv.weight",
# "ema_model.model.ups.2.2.to_out.0.weight", "ema_model.model.ups.2.2.to_out.0.bias",
# "ema_model.model.ups.2.2.to_out.1.g", "ema_model.model.ups.2.3.1.weight", "ema_model.model.ups.2.3.1.bias",
# "ema_model.model.ups.3.0.mlp.1.weight", "ema_model.model.ups.3.0.mlp.1.bias",
# "ema_model.model.ups.3.0.block1.proj.weight", "ema_model.model.ups.3.0.block1.proj.bias",
# "ema_model.model.ups.3.0.block1.norm.weight", "ema_model.model.ups.3.0.block1.norm.bias",
# "ema_model.model.ups.3.0.block2.proj.weight", "ema_model.model.ups.3.0.block2.proj.bias",
# "ema_model.model.ups.3.0.block2.norm.weight", "ema_model.model.ups.3.0.block2.norm.bias",
# "ema_model.model.ups.3.0.res_conv.weight", "ema_model.model.ups.3.0.res_conv.bias",
# "ema_model.model.ups.3.1.mlp.1.weight", "ema_model.model.ups.3.1.mlp.1.bias",
# "ema_model.model.ups.3.1.block1.proj.weight", "ema_model.model.ups.3.1.block1.proj.bias",
# "ema_model.model.ups.3.1.block1.norm.weight", "ema_model.model.ups.3.1.block1.norm.bias",
# "ema_model.model.ups.3.1.block2.proj.weight", "ema_model.model.ups.3.1.block2.proj.bias",
# "ema_model.model.ups.3.1.block2.norm.weight", "ema_model.model.ups.3.1.block2.norm.bias",
# "ema_model.model.ups.3.1.res_conv.weight", "ema_model.model.ups.3.1.res_conv.bias",
# "ema_model.model.ups.3.2.norm.g", "ema_model.model.ups.3.2.to_qkv.weight",
# "ema_model.model.ups.3.2.to_out.0.weight", "ema_model.model.ups.3.2.to_out.0.bias",
# "ema_model.model.ups.3.2.to_out.1.g", "ema_model.model.ups.3.3.weight", "ema_model.model.ups.3.3.bias",
# "ema_model.model.mid_block1.mlp.1.weight", "ema_model.model.mid_block1.mlp.1.bias",
# "ema_model.model.mid_block1.block1.proj.weight", "ema_model.model.mid_block1.block1.proj.bias",
# "ema_model.model.mid_block1.block1.norm.weight", "ema_model.model.mid_block1.block1.norm.bias",
# "ema_model.model.mid_block1.block2.proj.weight", "ema_model.model.mid_block1.block2.proj.bias",
# "ema_model.model.mid_block1.block2.norm.weight", "ema_model.model.mid_block1.block2.norm.bias",
# "ema_model.model.mid_attn.norm.g", "ema_model.model.mid_attn.to_qkv.weight",
# "ema_model.model.mid_attn.to_out.weight", "ema_model.model.mid_attn.to_out.bias",
# "ema_model.model.mid_block2.mlp.1.weight", "ema_model.model.mid_block2.mlp.1.bias",
# "ema_model.model.mid_block2.block1.proj.weight", "ema_model.model.mid_block2.block1.proj.bias",
# "ema_model.model.mid_block2.block1.norm.weight", "ema_model.model.mid_block2.block1.norm.bias",
# "ema_model.model.mid_block2.block2.proj.weight", "ema_model.model.mid_block2.block2.proj.bias",
# "ema_model.model.mid_block2.block2.norm.weight", "ema_model.model.mid_block2.block2.norm.bias",
# "ema_model.model.final_res_block.mlp.1.weight", "ema_model.model.final_res_block.mlp.1.bias",
# "ema_model.model.final_res_block.block1.proj.weight", "ema_model.model.final_res_block.block1.proj.bias",
# "ema_model.model.final_res_block.block1.norm.weight", "ema_model.model.final_res_block.block1.norm.bias",
# "ema_model.model.final_res_block.block2.proj.weight", "ema_model.model.final_res_block.block2.proj.bias",
# "ema_model.model.final_res_block.block2.norm.weight", "ema_model.model.final_res_block.block2.norm.bias",
# "ema_model.model.final_res_block.res_conv.weight", "ema_model.model.final_res_block.res_conv.bias",
# "ema_model.model.final_conv.weight", "ema_model.model.final_conv.bias".

# %% [markdown]
# # convnert ema to model

# %%
ema_model = {}
for key in ema_keys:
    if "ema_model." in key:
        ema_model[key[10:]] = ema_dict[key]
print(len(ema_model.keys()))
ema_model.keys()
# Out:
# 287
# dict_keys(['betas', 'alphas_cumprod', 'alphas_cumprod_prev', 'sqrt_alphas_cumprod', 'sqrt_one_minus_alphas_cumprod', 'log_one_minus_alphas_cumprod', 'sqrt_recip_alphas_cumprod', 'sqrt_recipm1_alphas_cumprod', 'posterior_variance', 'posterior_log_variance_clipped', 'posterior_mean_coef1', 'posterior_mean_coef2', 'loss_weight', 'model.init_conv.weight', 'model.init_conv.bias', 'model.time_mlp.1.weight', 'model.time_mlp.1.bias', 'model.time_mlp.3.weight', 'model.time_mlp.3.bias', 'model.downs.0.0.mlp.1.weight', 'model.downs.0.0.mlp.1.bias', 'model.downs.0.0.block1.proj.weight', 'model.downs.0.0.block1.proj.bias', 'model.downs.0.0.block1.norm.weight', 'model.downs.0.0.block1.norm.bias', 'model.downs.0.0.block2.proj.weight', 'model.downs.0.0.block2.proj.bias', 'model.downs.0.0.block2.norm.weight', 'model.downs.0.0.block2.norm.bias', 'model.downs.0.1.mlp.1.weight', 'model.downs.0.1.mlp.1.bias', 'model.downs.0.1.block1.proj.weight', 'model.downs.0.1.block1.proj.bias', 'model.downs.0.1.block1.norm.weight', 'model.downs.0.1.block1.norm.bias', 'model.downs.0.1.block2.proj.weight', 'model.downs.0.1.block2.proj.bias', 'model.downs.0.1.block2.norm.weight', 'model.downs.0.1.block2.norm.bias', 'model.downs.0.2.norm.g', 'model.downs.0.2.to_qkv.weight', 'model.downs.0.2.to_out.0.weight', 'model.downs.0.2.to_out.0.bias', 'model.downs.0.2.to_out.1.g', 'model.downs.0.3.1.weight', 'model.downs.0.3.1.bias', 'model.downs.1.0.mlp.1.weight', 'model.downs.1.0.mlp.1.bias', 'model.downs.1.0.block1.proj.weight', 'model.downs.1.0.block1.proj.bias', 'model.downs.1.0.block1.norm.weight', 'model.downs.1.0.block1.norm.bias', 'model.downs.1.0.block2.proj.weight', 'model.downs.1.0.block2.proj.bias', 'model.downs.1.0.block2.norm.weight', 'model.downs.1.0.block2.norm.bias', 'model.downs.1.1.mlp.1.weight', 'model.downs.1.1.mlp.1.bias', 'model.downs.1.1.block1.proj.weight', 'model.downs.1.1.block1.proj.bias', 'model.downs.1.1.block1.norm.weight', 'model.downs.1.1.block1.norm.bias', 'model.downs.1.1.block2.proj.weight', 'model.downs.1.1.block2.proj.bias', 'model.downs.1.1.block2.norm.weight', 'model.downs.1.1.block2.norm.bias', 'model.downs.1.2.norm.g', 'model.downs.1.2.to_qkv.weight', 'model.downs.1.2.to_out.0.weight', 'model.downs.1.2.to_out.0.bias', 'model.downs.1.2.to_out.1.g', 'model.downs.1.3.1.weight', 'model.downs.1.3.1.bias', 'model.downs.2.0.mlp.1.weight', 'model.downs.2.0.mlp.1.bias', 'model.downs.2.0.block1.proj.weight', 'model.downs.2.0.block1.proj.bias', 'model.downs.2.0.block1.norm.weight', 'model.downs.2.0.block1.norm.bias', 'model.downs.2.0.block2.proj.weight', 'model.downs.2.0.block2.proj.bias', 'model.downs.2.0.block2.norm.weight', 'model.downs.2.0.block2.norm.bias', 'model.downs.2.1.mlp.1.weight', 'model.downs.2.1.mlp.1.bias', 'model.downs.2.1.block1.proj.weight', 'model.downs.2.1.block1.proj.bias', 'model.downs.2.1.block1.norm.weight', 'model.downs.2.1.block1.norm.bias', 'model.downs.2.1.block2.proj.weight', 'model.downs.2.1.block2.proj.bias', 'model.downs.2.1.block2.norm.weight', 'model.downs.2.1.block2.norm.bias', 'model.downs.2.2.norm.g', 'model.downs.2.2.to_qkv.weight', 'model.downs.2.2.to_out.0.weight', 'model.downs.2.2.to_out.0.bias', 'model.downs.2.2.to_out.1.g', 'model.downs.2.3.1.weight', 'model.downs.2.3.1.bias', 'model.downs.3.0.mlp.1.weight', 'model.downs.3.0.mlp.1.bias', 'model.downs.3.0.block1.proj.weight', 'model.downs.3.0.block1.proj.bias', 'model.downs.3.0.block1.norm.weight', 'model.downs.3.0.block1.norm.bias', 'model.downs.3.0.block2.proj.weight', 'model.downs.3.0.block2.proj.bias', 'model.downs.3.0.block2.norm.weight', 'model.downs.3.0.block2.norm.bias', 'model.downs.3.1.mlp.1.weight', 'model.downs.3.1.mlp.1.bias', 'model.downs.3.1.block1.proj.weight', 'model.downs.3.1.block1.proj.bias', 'model.downs.3.1.block1.norm.weight', 'model.downs.3.1.block1.norm.bias', 'model.downs.3.1.block2.proj.weight', 'model.downs.3.1.block2.proj.bias', 'model.downs.3.1.block2.norm.weight', 'model.downs.3.1.block2.norm.bias', 'model.downs.3.2.norm ...

# %%
diffusion.load_state_dict(ema_model)
# Out:
# <All keys matched successfully>
